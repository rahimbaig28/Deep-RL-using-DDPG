# %% [markdown]
# <a href="https://colab.research.google.com/github/rahimbaig28/Deep-RL-using-DDPG/blob/main/deep_RL_agent_using_DDPG_to_control_a_pendulum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stable-baselines3[extra] gym
# !pip install gymnasium[classic-control] shimmy stable-baselines3[extra]

# %%
import gymnasium as gym
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise
import numpy as np

# Create Pendulum environment
env = gym.make("Pendulum-v1")

# Define action noise
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# Train DDPG model
model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=100_000)
model.save("ddpg_pendulum")

# Evaluate model
episodes = 5
for ep in range(episodes):
    obs, _ = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_reward += reward
    print(f"Episode {ep+1}: Total reward = {total_reward:.2f}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.48e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 40        |
# |    time_elapsed    | 19        |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 26.2      |
# |    critic_loss     | 0.0316    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.43e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 35        |
# |    time_elapsed    | 44        |
# |    total_timesteps | 1600      |
# ...
